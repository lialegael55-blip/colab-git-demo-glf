# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/lialegael55-blip/colab-git-demo-glf.git
# %cd colab-git-demo-glf
# !ls
# Out:
# Cloning into 'colab-git-demo-glf'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/colab-git-demo-glf
# README.md
